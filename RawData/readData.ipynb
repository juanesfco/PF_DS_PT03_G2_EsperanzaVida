# %%
import wbgapi as wb
import pandas as pd

nyCan = wb.data.DataFrame(['NY.GDP.PCAP.CD', 'SP.POP.TOTL'], mrv=5) # most recent 5 years 
nyCan
# Out:
#                               YR2018        YR2019        YR2020  \
# economy series
# ABW     NY.GDP.PCAP.CD  3.091852e+04  3.190276e+04  2.448786e+04
#         SP.POP.TOTL     1.059620e+05  1.064420e+05  1.065850e+05
# AFE     NY.GDP.PCAP.CD  1.550112e+03  1.499954e+03  1.353928e+03
#         SP.POP.TOTL     6.497571e+08  6.672430e+08  6.851130e+08
# AFG     NY.GDP.PCAP.CD  5.020571e+02  5.005230e+02  5.168668e+02
# ...                              ...           ...           ...
# ZAF     SP.POP.TOTL     5.733964e+07  5.808706e+07  5.880193e+07
# ZMB     NY.GDP.PCAP.CD  1.475200e+03  1.268121e+03  9.568317e+02
#         SP.POP.TOTL     1.783589e+07  1.838048e+07  1.892772e+07
# ZWE     NY.GDP.PCAP.CD  2.269177e+03  1.421869e+03  1.372697e+03
#         SP.POP.TOTL     1.505218e+07  1.535461e+07  1.566967e+07
#
#                               YR2021        YR2022
# economy series
# ABW     NY.GDP.PCAP.CD  2.934210e+04           NaN
# ...

# %%
wb.topic.info()
# Out:
# id    value
# ----  -------------------------------
# 1     Agriculture & Rural Development
# 2     Aid Effectiveness
# 3     Economy & Growth
# 4     Education
# 5     Energy & Mining
# 6     Environment
# 7     Financial Sector
# 8     Health
# 9     Infrastructure
# 10    Social Protection & Labor
# 11    Poverty
# 12    Private Sector
# 13    Public Sector
# 14    Science & Technology
# 15    Social Development
# 16    Urban Development
# 17    Gender
# 18    Millenium development goals
# 19    Climate Change
# 20    External Debt
# 21    Trade
#       21 elements

# %%
wb.series.info(topic=8)
# Out:
# id                 value
# -----------------  ----------------------------------------------------------------------------------------------------------------------------------------
# SP.POP.DPND        Age dependency ratio (% of working-age population)
# SH.STA.BRTC.ZS     Births attended by skilled health staff (% of total)
# SH.DTH.INJR.ZS     Cause of death, by injury (% of total)
# SH.HIV.0014        Children (0-14) living with HIV
# SH.MED.CMHW.P3     Community health workers (per 1,000 people)
# SP.REG.BRTH.RU.ZS  Completeness of birth registration, rural (%)
# SP.REG.DTHS.ZS     Completeness of death registration with cause-of-death information (%)
# SN.ITK.SALT.ZS     Consumption of iodized salt (% of households)
# SH.XPD.CHEX.PP.CD  Current health expenditure per capita, PPP (current international $)
# SH.STA.DIAB.ZS     Diabetes prevalence (% of population ages 20 to 79)
# ...
