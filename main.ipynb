# %%
indicators = ["GC.XPN.TOTL.GD.ZS", "NE.RSB.GNFS.CD", "NY.GDP.MKTP.KD.ZG", "NY.GDP.PCAP.CD",
                "NY.GNP.PCAP.CD", "SE.XPD.TOTL.GD.ZS", "SE.XPD.PRIM.PC.ZS", "SE.ADT.LITR.ZS",
                "SH.XPD.GHED.GD.ZS", "SP.DYN.LE00.IN", "SH.DYN.NMRT", "SH.DYN.MORT",
                "SN.ITK.DEFC.ZS","IP.PAT.RESD", "GB.XPD.RSDV.GD.ZS", "SP.POP.SCIE.RD.P6",
                "SI.POV.GINI", "VC.IHR.PSRC.P5", "SI.POV.NAHC", "SL.UEM.TOTL.ZS"]

# %%
from pyjstat import pyjstat

#storage_client = storage.Client()
#bucket = storage_client.get_bucket('worldbank-datalake')
#blob = bucket.blob('api.worldbank.org/v2/country/all/indicator/GB.XPD.RSDV.GD.ZS')
#contents = blob.download_as_string()
#dataset_from_json_string = pyjstat.Dataset.read(contents.decode("utf-8"))
#dataframe = dataset_from_json_string.write('dataframe')

URL = 'http://api.worldbank.org/v2/country/all/indicator/NY.GDP.PCAP.CD?format=jsonstat'
dataset = pyjstat.Dataset.read(URL)
dataframe = dataset.write('dataframe')

dataframe
# Out:
#                            Country                        Series  Year  \
# 0      Africa Eastern and Southern  GDP per capita (current US$)  1960
# 1      Africa Eastern and Southern  GDP per capita (current US$)  1961
# 2      Africa Eastern and Southern  GDP per capita (current US$)  1962
# 3      Africa Eastern and Southern  GDP per capita (current US$)  1963
# 4      Africa Eastern and Southern  GDP per capita (current US$)  1964
# ...                            ...                           ...   ...
# 16753                     Zimbabwe  GDP per capita (current US$)  2018
# 16754                     Zimbabwe  GDP per capita (current US$)  2019
# 16755                     Zimbabwe  GDP per capita (current US$)  2020
# 16756                     Zimbabwe  GDP per capita (current US$)  2021
# 16757                     Zimbabwe  GDP per capita (current US$)  2022
#
#              value
# 0       161.638982
# 1       161.111657
# 2       170.538537
# 3       198.038919
# 4       178.019217
# ...            ...
# 16753  2269.177012
# 16754  1421.868596
# 16755  1372.696674
# 16756  1773.920411
# 16757  1266.996031
#
# [16758 rows x 4 columns]
